# %% [markdown]
# <a href="https://colab.research.google.com/github/An0816/PyTorchZeroToAll/blob/main/lec6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# - Binary prediction (0 or 1) is useful
# : real number 대신 binary number로 어떻게 바꾸는가?
#   -> use **Sigmoid**
# : 0 <= y hat <= 1

# %% [markdown]
# ![lec6-1.png](data:image/png;base64,...)

# %% [markdown]
# - How can we predict?
# y hat > 0.5 : predict as 1
# other than, predict as 0
#
# - sigmoid에는 (binary) Cross Entropy Loss 사용(instead of MSE)
# - prediction이 맞다면 loss가 작음

# %% [markdown]
# - Code에서 Sigmoid 사용하기
# : 'torch.nn.functional.sigmoid`

# %% [markdown]
# **Logistic Regression**
# 1. Design your model using class
# x -> linear -> sigmoid -> y hat
# 2. Construct loss and optimizer(BCELoss, SGD)
# 3. training cycle(forward, back propagation)

# %% [markdown]
# **Activate Function**
# 1. sigmoid
# 2. etc

# %%
import torch
from torch.autograd import Variable


x_data = Variable(torch.Tensor([[1.0], [2.0], [3.0]]))
y_data = Variable(torch.Tensor([[2.0], [4.0], [6.0]]))

class Model(torch.nn.Module):
    def __init__(self):
        super(Model, self).__init__()
        self.linear = torch.nn.Linear(1, 1)
    def forward(self, x):
        y_pred = torch.sigmoid(self.linear(x))
        return y_pred

model = Model()

criterion = torch.nn.BCELoss(size_average = True)
optimizer = torch.optim.SGD(model.parameters(), lr = 0.01)

for epoch in range(1000):
    y_pred = model(x_data)

    loss = criterion(y_pred, y_data)
    print(epoch, loss.data)

    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

hour_var = Variable(torch.Tensor([[1.0]]))
print("predict 1 hour ", 1.0, model(hour_var).data[0][0] > 0.5)
hour_var = Variable(torch.Tensor([[7.0]]))
print("predict 7 hours", 7.0, model(hour_var).data[0][0] > 0.5)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='mean' instead.
#   warnings.warn(warning.format(ret))
# 0 tensor(1.2556)
# 1 tensor(0.4271)
# 2 tensor(-0.3787)
# 3 tensor(-1.1630)
# 4 tensor(-1.9274)
# 5 tensor(-2.6737)
# 6 tensor(-3.4040)
# 7 tensor(-4.1204)
# 8 tensor(-4.8245)
# 9 tensor(-5.5182)
# 10 tensor(-6.2030)
# 11 tensor(-6.8801)
# 12 tensor(-7.5507)
# 13 tensor(-8.2157)
# 14 tensor(-8.8758)
# 15 tensor(-9.5319)
# 16 tensor(-10.1845)
# 17 tensor(-10.8340)
# 18 tensor(-11.4808)
# 19 tensor(-12.1254)
# 20 tensor(-12.7680)
# 21 tensor(-13.4090)
# 22 tensor(-14.0483)
# 23 tensor(-14.6864)
# 24 tensor(-15.3233)
# 25 tensor(-15.9593)
# 26 tensor(-16.5944)
# 27 tensor(-17.2284)
# 28 tensor(-17.8621)
# 29 tensor(-18.4948)
# 30 tensor(-19.1271)
# 31 tensor(-19.7593)
# 32 tensor(-20.3903)
# 33 tensor(-21.0220)
# 34 tensor(-21.6522)
# 35 tensor(-22.2833)
# 36 tensor(-22.9131)
# ...
